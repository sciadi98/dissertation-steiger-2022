# %%
# %run common.ipynb
# Out:
# ...
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: C:\Users\natha\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
# Parameters
input_cols = ['shape', 'profile_entrance', 'profile_exit', 'rising_entrance', 'rising_exit', 'shards', 'fethering', 'entrance_mounding', 'center_mounding', 'exit_mounding', 'mounding']
result_col = 'result'
train_dataset_file = 'DATA/Train/Final_dataset.xlsx'
test_dataset_file = 'DATA/Validation/Dataset_da_validare.xlsx'

# %%
display_input_data(
    train_dataset_file,
    input_cols
)
# Out:
#      shape_E  shape_indeterminate  profile_entrance_V  profile_exit_V  \
# 0          0                    1                   1               1
# 1          0                    1                   0               1
# 2          0                    1                   0               1
# 3          0                    1                   0               1
# 4          0                    1                   0               1
# ..       ...                  ...                 ...             ...
# 275        1                    0                   1               1
# 276        1                    0                   1               0
# 277        1                    0                   1               1
# 278        1                    0                   1               1
# 279        1                    0                   1               1
#
#      rising_entrance_bilateral  rising_entrance_single  rising_exit_bilateral  \
# ...

# %%
check_input_data_indices(train_dataset_file, test_dataset_file, input_cols)
# Out:
# Datasets are compatible

# %%
model = train_model(
    train_dataset_file,
    input_cols,
    result_col
)
model
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %%
evaluate_model(
    model,
    test_dataset_file,
    input_cols,
    result_col
)
# Out:
# 0.7164179104477612

# %%
run_input_optimizer(train_dataset_file, test_dataset_file, input_cols, result_col)
# Out:
# Testing combinations of length 2
# Testing combinations of length 3
# Testing combinations of length 4
# Testing combinations of length 5
# Testing combinations of length 6
# Testing combinations of length 7
# Testing combinations of length 8
# Testing combinations of length 9
# Testing combinations of length 10
# Testing combinations of length 11
# Max score: 0.8805970149253731
# Best columns combination: ('shape', 'profile_entrance', 'rising_entrance', 'shards', 'mounding')
# Min score: 0.4626865671641791
# Worse columns combination: ('fethering', 'entrance_mounding')

# %%
display_correlation_matrix(train_dataset_file, input_cols)
